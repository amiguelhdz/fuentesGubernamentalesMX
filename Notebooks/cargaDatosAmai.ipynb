# %%
import pandas as pd
import numpy as np
import os
from pathlib import Path

# %% [markdown]
# # Path de los datos

# %%
pathDatos = Path('..') / 'Datos' / 'AMAI_NSE_AGEB'
print(pathDatos)
# Out:
# ..\Datos\AMAI_NSE_AGEB

# %%
names=['estado',
       'nombreEstado',
       'municipio',
       'nombreMunicipio',
       'localidad',
       'nombreLocalidad',
       'ageb',
       'viviendasAB',
       'viviendasCMas',
       'viviendasC',
       'viviendasCMenos',
       'viviendasDMas',
       'viviendasD',
       'viviendasE',
       'nsePredominante',
       'totViviendas',
       'tamanioLocalidad'
      ]

# %%
df = pd.read_excel(Path(pathDatos / 'NSE_por_AGEB_AMAI.xlsx'), skiprows=2, names=names)

# %%
df.head()
# Out:
#    estado    nombreEstado  municipio nombreMunicipio  localidad  \
# 0       1  Aguascalientes          1  Aguascalientes          1
# 1       1  Aguascalientes          1  Aguascalientes          1
# 2       1  Aguascalientes          1  Aguascalientes          1
# 3       1  Aguascalientes          1  Aguascalientes          1
# 4       1  Aguascalientes          1  Aguascalientes          1
#
#   nombreLocalidad  ageb viviendasAB viviendasCMas viviendasC viviendasCMenos  \
# 0  Aguascalientes  006A         178           124         60              24
# 1  Aguascalientes  0106         183           375        247             128
# 2  Aguascalientes  0163          35           157        228             167
# 3  Aguascalientes  0182         345           187         63              46
# 4  Aguascalientes  0229          25            36         14              20
#
#   viviendasDMas viviendasD viviendasE nsePredominante totViviendas  \
# ...
